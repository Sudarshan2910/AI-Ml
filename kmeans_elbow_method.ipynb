# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=800, n_features=3,centers=4)
X
# Out:
# array([[-3.71691159,  7.67894393,  7.87560436],
#        [-6.48907494, -8.04017553,  2.59313645],
#        [-4.86137931, -9.82070524,  2.67357388],
#        ...,
#        [-7.64239586, -0.72366777, -9.45811062],
#        [-2.94719159, 10.25911631, -7.54427356],
#        [-2.84966459,  7.23689828,  6.72233189]])

# %%
wcss_list=[]

# %%
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss_list)
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS List")
plt.xticks(range(1,11))
plt.grid(True)
plt.show()
