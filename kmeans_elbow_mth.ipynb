# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=800, n_features=3,centers=4)
X
# Out:
# array([[ 3.72179651, -6.18077763, -2.40633748],
#        [-3.97775215,  1.54354482, -6.14670939],
#        [-5.56727091,  8.63413782, -2.50337769],
#        ...,
#        [-4.61650512,  1.56254391, -6.71065968],
#        [10.30433708,  7.45911219, -8.56217203],
#        [ 1.19269286, -4.98367922, -1.61361184]])

# %%
wcss_list=[]

# %%
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss_list)
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS List")
plt.xticks(range(1,11))
plt.grid(True)
plt.show()
